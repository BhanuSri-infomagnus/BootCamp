# %%
print(1+2)
# Out:
# 3

# %%
pip install pyodbc
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pymssql
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Failed to build pymssql
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Building wheel for pymssql (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [36 lines of output]
#       prefix='/usr/local'
#       setup.py: platform.system() => Windows
#       setup.py: platform.architecture() => ('64bit', 'WindowsPE')
#       setup.py: include_dirs => ['/usr/local\\include']
#       setup.py: library_dirs => ['/usr/local\\lib']
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
# ...

# %%
import pyodbc # type: ignore
conn_str = (
    "DRIVER=SQL Server;"
    "SERVER=DESKTOP-OK8NL61\\SQLEXPRESS;"
    "DATABASE=AdventureWorksDW2022;"
    "UID=Bhanu;"
    "PWD=admin"
)
# Establish the connection
conn = pyodbc.connect(conn_str)
# Create a cursor object
cursor = conn.cursor()
# Execute a query
cursor.execute("SELECT top 10 * FROM DimEmployee")
# Fetch and print the results
for row in cursor.fetchall():
    print(row)
cursor.execute("SELECT count(distinct EmployeeKey) FROM DimEmployee")
# Fetch and print the results
for row in cursor.fetchall():
    print(row)
cursor.execute("SELECT gender,count(distinct EmployeeKey) FROM DimEmployee group by gender")
# Fetch and print the results
for row in cursor.fetchall():
    print(row)
cursor.execute("SELECT count(distinct EmployeeKey) FROM DimEmployee where Status='current'")
# Fetch and print the results
for row in cursor.fetchall():
    print(row)
cursor.execute("SELECT top 10 concat(FirstName,LastName) FROM DimEmployee")
# Fetch and print the results
for row in cursor.fetchall():
    print(row)
cursor.execute("SELECT a.EmployeeFullName as Employee,b.EmployeeFUllName as Manager FROM DimEmployee as a join DimEmployee as b on a.ParentEmployeeKey=b.EmployeeKey")
# Fetch and print the results
for row in cursor.fetchall():
    print(row)
# Close the connection
conn.close()
# Out:
# (1, 18, '14417807', None, 11, 'Guy', 'Gilbert', 'R', False, 'Production Technician - WC60', '2006-01-28', '1981-11-12', 'adventure-works\\guy1', 'guy1@adventure-works.com', '320-555-0195', 'M', 'Guy Gilbert', '320-555-0195', False, 'M', 1, Decimal('12.4500'), 21, 30, True, False, 'Production', '2006-01-28', None, 'Current', b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00H\x00H\x00\x00\xff\xed\x00\xd8Photoshop 3.0\x008BIM\x04\x04\x00\x00\x00\x00\x00\xbc\x1c\x01Z\x00\x03\x1b%G\x1c\x02\x00\x00\x02\x00\x02\x1c\x02x\x00;Successful mature business man with hands folded over white\x1c\x02i\x00\x048837\x1c\x02\x05\x00.Senior business man with hands folded on white\x1c\x02\x19\x00\x03CRM\x1c\x02\x19\x00\x0eDigital Camera\x1c\x02\x19\x00\x11Change Management\xff\xdb\x00C\x00\x02\x01\x01\x02\x01\x01\x02\x02\x02\x02\x02\x02\x02\x02\x03\x05\x03\x03\x03\x03\x03\x06\x04\x04\x03\x05\x07\x06\x07\x07\x07\x06\x07\x07\x08\t\x0b\t\x08\x08\n\x08\x07\x07\n\r\n\n\x0b\x0c\x0c\x0c\x0c\x07\t\x0e\x0f\r\x0c\x
# ...
